# %%
import pandas as pd

# %%
df = pd.read_csv("bigtable20160527.csv")

# %%
df
# Out:
#               date  wd  holiday  dist     P1    P2   P3    P4    P5    P6  \
# 0       2016-01-01   0        1     1    913    83  332   415   249    83
# 1       2016-01-01   0        1     2  10790  1079  332  5395  6557  2988
# 2       2016-01-01   0        1     3      0     0    0     0    83    83
# 3       2016-01-01   0        1     4     83    83    0    83   166    83
# 4       2016-01-01   0        1     5     83     0    0    83     0     0
# 5       2016-01-01   0        1     6     83     0    0   249   166     0
# 6       2016-01-01   0        1     7    249     0   83     0    83     0
# 7       2016-01-01   0        1     8     83     0    0     0     0     0
# 8       2016-01-01   0        1     9    415     0    0   332   249   249
# 9       2016-01-01   0        1    10    747   332    0   996   747   166
# 10      2016-01-01   0        1    11    166     0   83    83     0     0
# 11      2016-01-01   0        1    12   1245    83    0  2324   913     0
# ...
